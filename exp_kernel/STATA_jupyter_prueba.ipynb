# %%
#pip install ipystata

import pandas as pd
import ipystata

# %%
df=pd.read_csv('data/IDEFC_NM_jun22.csv', encoding = "ISO-8859-1")
df.columns=df.columns.str.lower().str.replace(' ','_').str.replace('ñ','ny').str.replace('í','i')

# %%
# %%stata -d df
# egen total = rowtotal(enero-diciembre)
# graph bar (sum) total, over(anyo)
