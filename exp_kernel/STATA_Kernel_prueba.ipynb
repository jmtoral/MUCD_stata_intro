// %%
display "Hola Mundo, ¿me creían muertx? ¡Jamás! Soy STATA FTW"
// Out:
// Hola Mundo, ¿me creían muertx? ¡Jamás! Soy STATA FTW

// %%
import delimited "C:/Users/User/Downloads/IDEFC_NM_jun22.csv", clear

rename año yr
rename bienjurídicoafectado bien_juridico
egen total = rowtotal(enero-diciembre) 
d
// Out:
// (19 vars, 25,088 obs)
//
//
//
//
//
// Contains data
//   obs:        25,088
//  vars:            20
// --------------------------------------------------------------------------------
//               storage   display    value
// variable name   type    format     label      variable label
// --------------------------------------------------------------------------------
// yr              int     %8.0g                 Año
// clave_ent       byte    %8.0g                 Clave_Ent
// entidad         str31   %31s                  Entidad
// bien_juridico   str52   %52s                  Bien jurídico afectado
// tipodedelito    str78   %78s                  Tipo de delito
// subtipodedelito str78   %78s                  Subtipo de delito
// modalidad       str84   %84s                  Modalidad
// enero           int     %8.0g                 Enero
// febrero         int     %8.0g                 Febrero
// marzo           int     %8.0g                 Marzo
// ...

// %%
graph bar (sum) total, over(yr)
// Out:
// This front-end cannot display the desired image type.
